# %% [markdown]
# # > Importando bibliotecas a serem usadas

# %%
import keras
from keras.models import Model
from keras.layers import *
from keras.optimizers import *
from keras.losses import *
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.applications.inception_v3 import InceptionV3
from keras.applications.mobilenet import MobileNet
from keras.datasets import mnist

from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import pandas as pd
import matplotlib.image as mpimg
import cv2
import glob
import h5py
import random
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # > Entrada dos dados:

# %%
with h5py.File('dataset.h5','r') as hf:
    X = hf['X'][:]
    y = hf['y'][:]
    X_test = hf['X_test'][:]

# %% [markdown]
# # > Parâmetros:

# %%
batch_size_value = 64
num_epochs = 30
learning_rate = 2.0
seed = 42

# %% [markdown]
# # <font color=red>A. Data augmentation</font>

# %%
print(np.shape(X))
print(np.shape(X_test))
# Out:
# (150, 256, 256)
# (50, 256, 256)

# %% [markdown]
# ## 1. Definindo os parâmetros:

# %%
angulo_rot = 40
shift_largura = 0.2
shift_altura = 0.2
espelhar = True
distorcer_taxa = 0.2
zoom_taxa = 0.2

datagen = ImageDataGenerator(
        rotation_range=angulo_rot,
        width_shift_range=shift_largura,
        height_shift_range=shift_altura,
        shear_range=distorcer_taxa,
        zoom_range=zoom_taxa,
        horizontal_flip=espelhar,
        fill_mode='nearest')

# %% [markdown]
# ## 2. Aplicando a transformação:

# %%
i = 0
img = X[0].reshape(1, 256, 256, 1)

for batch in datagen.flow(img, batch_size=1,
                          save_to_dir='preview', save_prefix='cat', save_format='jpeg'):
    i += 1
    if i > 2:
        break  # otherwise the generator would loop indefinitely
        
print("Imagem Original")
plt.imshow(img.reshape(256, 256), cmap='gray'),plt.show()
print("Imagens Geradas com Data Augmentation")

for file in glob.glob("preview\*.jpeg"):
    img = mpimg.imread(file)
    plt.imshow(img.reshape(256, 256), cmap='gray'),plt.show()
# Out:
# Imagem Original
# Imagens Geradas com Data Augmentation

# %% [markdown]
# # <font color=red> B. Um primeiro treinamento: </font>

# %% [markdown]
# ## 1. Divisão da base de dados:

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.20, random_state = seed)

# %% [markdown]
# ## 2. Normalização e preparação dos dados para treinamento:

# %%
X_train = X_train.astype('float32')
X_val = X_val.astype('float32')
X_test = X_test.astype('float32')

X_train /=  255
X_val  /=  255
X_test /=  255

X_train = X_train.reshape(-1,256,256,1)
X_val = X_val.reshape(-1,256,256,1)
X_test = X_test.reshape(-1,256,256,1)

# %% [markdown]
# ## 3. Definição da Arquitetura:

# %%
inputs = Input((256, 256,1))
Conv = Conv2D(1, kernel_size = (3,3), strides = (5, 5), padding = 'same', activation = 'linear')(inputs)
Conv = Conv2D(1, kernel_size = (3,3), strides = (5, 5), padding = 'same', activation = 'linear')(Conv)
flat = Flatten()(Conv)
dense = Dense(2,activation  =  'tanh')(flat)
dense = Dense(1, activation  =  'sigmoid')(dense)

model = Model(inputs, dense)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 256, 256, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 52, 52, 1)         10
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 1)         10
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 121)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 244
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 267
# Trainable params: 267
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 4. Definindo os parâmetros de Otimização:

# %%
model.compile(loss = 'mean_squared_error',optimizer = SGD(lr = learning_rate), metrics = ['acc'])

# %% [markdown]
# ## 5. Treinando:

# %%
history = model.fit(X_train, y_train,
          batch_size = batch_size_value,
          epochs = num_epochs,
          verbose = 1,
          validation_data = (X_val, y_val))
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/30
# 120/120 [==============================] - 2s 21ms/step - loss: 0.2559 - acc: 0.5083 - val_loss: 0.2518 - val_acc: 0.5000
# Epoch 2/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.2469 - acc: 0.5417 - val_loss: 0.2384 - val_acc: 0.5667
# Epoch 3/30
# 120/120 [==============================] - 0s 443us/step - loss: 0
per left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('época')
plt.legend(['treino', 'teste'], loc = 'upper left')
plt.show()

# %% [markdown]
# ### 7. Salvando o arquivo com o desempenho obtido:

# %%
prediction  =  model.predict(X_test)
np.savetxt('resultado.csv', prediction)

# %% [markdown]
# # <font color=red> C. Modificando a arquitetura </font>

# %% [markdown]
# ## 1. Numero de filtros por camada

# %%
num_filtros_camada_1 = 32
num_filtros_camada_2 = 64

num_neuronios_camada_1 = 64
num_neuronios_camada_2 = 1

# %%
Conv = Conv2D(num_filtros_camada_1, kernel_size = (3,3), strides = (5, 5), padding = 'same', activation = 'linear')(inputs)
Conv = Conv2D(num_filtros_camada_1, kernel_size = (3,3), strides = (5, 5), padding = 'same', activation = 'linear')(Conv)

Conv = Conv2D(num_filtros_camada_2, kernel_size = (3,3), strides = (5, 5), padding = 'same', activation = 'linear')(Conv)
Conv = Conv2D(num_filtros_camada_2, kernel_size = (3,3), strides = (5, 5), padding = 'same', activation = 'linear')(Conv)

flat = Flatten()(Conv)

dense = Dense(num_neuronios_camada_1,activation  =  'tanh')(flat)
dense = Dense(num_neuronios_camada_1,activation  =  'tanh')(dense)
dense = Dense(num_neuronios_camada_2, activation  =  'sigmoid')(dense)

model = Model(inputs, dense)
model.compile(loss = 'mean_squared_error', optimizer = SGD(lr = learning_rate), metrics = ['acc'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 256, 256, 1)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 32)        320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 32)        9248
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 64)          18496
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 64)          36928
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 73,377
# Trainable params: 73,377
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #  <font color=red> D. Variando taxa de aprendizado <color>

# %% [markdown]
# ### 1. Taxa de Aprendizado igual a 3.0:

# %%
# Variar a taxa de aprendizado e verificar o impacto no treinamento

learning_rate = 3

model.compile(loss = 'mean_squared_error', optimizer = SGD(lr = learning_rate), metrics = ['acc'])
history = model.fit(X_train, y_train,
          batch_size = batch_size_value,
          epochs = num_epochs,
          verbose = 1,
          validation_data = (X_val, y_val))
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.2814 - acc: 0.5667 - val_loss: 0.2736 - val_acc: 0.5000
# Epoch 2/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.3580 - acc: 0.4667 - val_loss: 0.4885 - val_acc: 0.5000
# Epoch 3/30
# 120/120 [==============================] - 0s 509us/step - loss: 0.4495 - acc: 0.4833 - val_loss: 0.4995 - val_acc: 0.5000
# Epoch 4/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4828 - acc: 0.5167 - val_loss: 0.4991 - val_acc: 0.5000
# Epoch 5/30
# 120/120 [==============================] - 0s 535us/step - loss: 0.4822 - acc: 0.5167 - val_loss: 0.4940 - val_acc: 0.5000
# Epoch 6/30
# 120/120 [==============================] - 0s 526us/step - loss: 0.4612 - acc: 0.5167 - val_loss: 0.4820 - val_acc: 0.5000
# Epoch 7/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4230 - acc: 0.4833 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 8/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 9/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 10/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 11/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 12/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 13/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 14/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 15/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 16/30
# 120/120 [==============================] - 0s 493us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 17/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 18/30
# 120/120 [==============================] - 0s 493us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 19/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 20/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 21/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 22/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 23/30
# 120/120 [==============================] - 0s 535us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 24/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 25/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 26/30
# 120/120 [==============================] - 0s 526us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 27/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 28/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 29/30
# 120/120 [==============================] - 0s 535us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 30/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000

# %% [markdown]
# ### 2. Taxa de Aprendizado igual a 1.0:

# %%
# Variar a taxa de aprendizado e verificar o impacto no treinamento

learning_rate = 0.5

model.compile(loss = 'mean_squared_error',optimizer = SGD(lr = learning_rate), metrics = ['acc'])
history = model.fit(X_train, y_train,
          batch_size = batch_size_value,
          epochs = num_epochs,
          verbose = 1,
          validation_data = (X_val, y_val))
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 2/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 3/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 4/30
# 120/120 [==============================] - 0s 535us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 5/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 6/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 7/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 8/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 9/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 10/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 11/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 12/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 13/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 14/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 15/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 16/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 17/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 18/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 19/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 20/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 21/30
# 120/120 [==============================] - 0s 493us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 22/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 23/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 24/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 25/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 26/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 27/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 28/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 29/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 30/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000

# %% [markdown]
# ### 3. Taxa de aprendizado (learning_rate) - Modifique manualmente:

# %%
# Variar a taxa de aprendizado e verificar o impacto no treinamento

# Inserir nova learning_rate

#nova_learning_rate = novo_valor
#learning_rate = nova_learning_rate

model.compile(loss = 'mean_squared_error', optimizer = SGD(lr = learning_rate), metrics = ['acc'])
history = model.fit(X_train, y_train,
          batch_size = batch_size_value,
          epochs = num_epochs,
          verbose = 1,
          validation_data = (X_val, y_val))
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 2/30
# 120/120 [==============================] - 0s 535us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 3/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 4/30
# 120/120 [==============================] - 0s 526us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 5/30
# 120/120 [==============================] - 0s 543us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 6/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 7/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 8/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 9/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 10/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 11/30
# 120/120 [==============================] - 0s 526us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 12/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 13/30
# 120/120 [==============================] - 0s 526us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 14/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 15/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 16/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 17/30
# 120/120 [==============================] - 0s 526us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 18/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 19/30
# 120/120 [==============================] - 0s 526us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 20/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 21/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 22/30
# 120/120 [==============================] - 0s 485us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 23/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 24/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 25/30
# 120/120 [==============================] - 0s 526us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 26/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 27/30
# 120/120 [==============================] - 0s 501us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 28/30
# 120/120 [==============================] - 0s 518us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 29/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 30/30
# 120/120 [==============================] - 0s 510us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000

# %% [markdown]
# #  <font color=red>E. Variar o parâmetro Batch Size<font>

# %% [markdown]
# ### 1. Batch Size = 32

# %%
batch_size_value = 32

model.compile(loss = 'mean_squared_error', optimizer = SGD(lr = learning_rate), metrics = ['acc'])
history = model.fit(X_train, y_train,
          batch_size = batch_size_value,
          epochs = num_epochs,
          verbose = 1,
          validation_data = (X_val, y_val))
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 2/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 3/30
# 120/120 [==============================] - 0s 593us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 4/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 5/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 6/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 7/30
# 120/120 [==============================] - 0s 660us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 8/30
# 120/120 [==============================] - 0s 568us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 9/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 10/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 11/30
# 120/120 [==============================] - 0s 568us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 12/30
# 120/120 [==============================] - 0s 577us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 13/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 14/30
# 120/120 [==============================] - 0s 593us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 15/30
# 120/120 [==============================] - 0s 577us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 16/30
# 120/120 [==============================] - 0s 577us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 17/30
# 120/120 [==============================] - 0s 602us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 18/30
# 120/120 [==============================] - 0s 593us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 19/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 20/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 21/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 22/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 23/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 24/30
# 120/120 [==============================] - 0s 577us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 25/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 26/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 27/30
# 120/120 [==============================] - 0s 577us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 28/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 29/30
# 120/120 [==============================] - 0s 585us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 30/30
# 120/120 [==============================] - 0s 577us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000

# %% [markdown]
# ### 2. Batch Size = 128

# %%
batch_size_value = 128

model.compile(loss = 'mean_squared_error', optimizer = SGD(lr = learning_rate), metrics = ['acc'])
history = model.fit(X_train, y_train,
          batch_size = batch_size_value,
          epochs = num_epochs,
          verbose = 1,
          validation_data = (X_val, y_val))
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 2/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 3/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 4/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 5/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 6/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 7/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 8/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 9/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 10/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 11/30
# 120/120 [==============================] - 0s 468us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 12/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 13/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 14/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 15/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 16/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 17/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 18/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 19/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 20/30
# 120/120 [==============================] - 0s 468us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 21/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 22/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 23/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 24/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 25/30
# 120/120 [==============================] - 0s 476us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 26/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 27/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 28/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 29/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 30/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000

# %% [markdown]
# ### 3. Batch Size - Modifique manualmente

# %%
#batch_size_value = novo_valor

# %%
model.compile(loss = 'mean_squared_error', optimizer = SGD(lr = learning_rate), metrics = ['acc'])
history = model.fit(X_train, y_train,
          batch_size = batch_size_value,
          epochs = num_epochs,
          verbose = 1,
          validation_data = (X_val, y_val))
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 2/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 3/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 4/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 5/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 6/30
# 120/120 [==============================] - 0s 476us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 7/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 8/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 9/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 10/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 11/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 12/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 13/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 14/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 15/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 16/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 17/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 18/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 19/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 20/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 21/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 22/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 23/30
# 120/120 [==============================] - 0s 485us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 24/30
# 120/120 [==============================] - 0s 459us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 25/30
# 120/120 [==============================] - 0s 468us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 26/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 27/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 28/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 29/30
# 120/120 [==============================] - 0s 468us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 30/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000

# %%
history = model.fit(X_train, y_train,
          batch_size = batch_size_value,
          epochs = num_epochs,
          verbose = 1,
          validation_data = (X_val, y_val))
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 2/30
# 120/120 [==============================] - 0s 426us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 3/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 4/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 5/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 6/30
# 120/120 [==============================] - 0s 468us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 7/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 8/30
# 120/120 [==============================] - 0s 426us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 9/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 10/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 11/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 12/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 13/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 14/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 15/30
# 120/120 [==============================] - 0s 434us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 16/30
# 120/120 [==============================] - 0s 426us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 17/30
# 120/120 [==============================] - 0s 468us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 18/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 19/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 20/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 21/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 22/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 23/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 24/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 25/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 26/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 27/30
# 120/120 [==============================] - 0s 460us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 28/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 29/30
# 120/120 [==============================] - 0s 443us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000
# Epoch 30/30
# 120/120 [==============================] - 0s 451us/step - loss: 0.4833 - acc: 0.5167 - val_loss: 0.5000 - val_acc: 0.5000

# %% [markdown]
# # <font color=red>F. Transfer Learning <font>

# %% [markdown]
# ### 1. Leitura da base de dados EMNIST:

# %%
X_train = np.load('X_train.npy')
X_val = np.load('X_val.npy')
y_train = np.load('y_train.npy')
y_val = np.load('y_val.npy')
print(np.shape(X_train))
print(np.shape(X_val))
# Out:
# (3993, 28, 28, 1)
# (999, 28, 28, 1)

# %% [markdown]
# ### 2. Conversão para One-Hot Encoding:

# %%
y_train2 = keras.utils.to_categorical(np.subtract(y_train,1), 26)
y_test2 = keras.utils.to_categorical(np.subtract(y_val,1), 26)

# %% [markdown]
# ### 3. Treinando um modelo SEM transfer learning:

# %% [markdown]
# #### > Definindo a Arquitetura

# %%
model_transfer_learning = Sequential()
model_transfer_learning.add(Conv2D(32, kernel_size=(5, 5), strides=(1, 1),
                 activation='relu',
                 input_shape=(28, 28, 1)))
model_transfer_learning.add(Conv2D(64, (3, 3), activation='relu'))
model_transfer_learning.add(Conv2D(64, (3, 3), activation='relu'))
model_transfer_learning.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_transfer_learning.add(Conv2D(64, (3, 3), activation='relu'))
model_transfer_learning.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_transfer_learning.add(Conv2D(64, (3, 3), activation='relu'))
model_transfer_learning.add(MaxPooling2D(pool_size=(2, 2)))
model_transfer_learning.add(Flatten())
model_transfer_learning.add(Dense(128, activation='relu'))
model_transfer_learning.add(Dense(26, activation='softmax'))

model_transfer_learning.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 22, 22, 64)        18496
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 20, 20, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 2, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_7 (Dense)              (None, 26)                3354
# =================================================================
# Total params: 141,786
# Trainable params: 141,786
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### > Treinamento:

# %%
model_transfer_learning.compile(loss=categorical_crossentropy,
              optimizer=RMSprop(lr=0.01),
              metrics=['accuracy'])

history_transfer_learning = model_transfer_learning.fit(X_train, y_train2,
          batch_size=batch_size_value,
          epochs=30,
          verbose=1,
          validation_data=(X_val, y_test2))
# Out:
# Train on 3993 samples, validate on 999 samples
# Epoch 1/30
# 3993/3993 [==============================] - 1s 306us/step - loss: 15.1771 - acc: 0.0338 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 2/30
# 3993/3993 [==============================] - 1s 152us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 3/30
# 3993/3993 [==============================] - 1s 147us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 4/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 5/30
# 3993/3993 [==============================] - 1s 148us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 6/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 7/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 8/30
# 3993/3993 [==============================] - 1s 149us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 9/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 10/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 11/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 12/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 13/30
# 3993/3993 [==============================] - 1s 148us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 14/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 15/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 16/30
# 3993/3993 [==============================] - 1s 148us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 17/30
# 3993/3993 [==============================] - 1s 148us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 18/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 19/30
# 3993/3993 [==============================] - 1s 149us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 20/30
# 3993/3993 [==============================] - 1s 146us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 21/30
# 3993/3993 [==============================] - 1s 151us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 22/30
# 3993/3993 [==============================] - 1s 149us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 23/30
# 3993/3993 [==============================] - 1s 151us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 24/30
# 3993/3993 [==============================] - 1s 148us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 25/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 26/30
# 3993/3993 [==============================] - 1s 151us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 27/30
# 3993/3993 [==============================] - 1s 149us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 28/30
# 3993/3993 [==============================] - 1s 150us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 29/30
# 3993/3993 [==============================] - 1s 151us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460
# Epoch 30/30
# 3993/3993 [==============================] - 1s 148us/step - loss: 15.5570 - acc: 0.0348 - val_loss: 15.3759 - val_acc: 0.0460

# %% [markdown]
# #### > Exibindo o desempenho:

# %%
plt.plot(history_transfer_learning.history['acc'])
plt.plot(history_transfer_learning.history['val_acc'])
plt.ylabel('acurácia')
plt.xlabel('época')
plt.legend(['treino', 'teste'], loc = 'upper left')
plt.show()

plt.plot(history_transfer_learning.history['loss'])
plt.plot(history_transfer_learning.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('época')
plt.legend(['treino', 'teste'], loc = 'upper left')
plt.show()

# %% [markdown]
# ## <font color=red>6. Treinando um modelo COM transfer learning<font>
#
# #### > Definindo a Arquitetura

# %%
model_transfer_learning = Sequential()
model_transfer_learning.add(Conv2D(32, kernel_size=(5, 5), strides=(1, 1),
                 activation='relu',
                 input_shape=(28, 28, 1)))
model_transfer_learning.add(Conv2D(64, (3, 3), activation='relu'))
model_transfer_learning.add(Conv2D(64, (3, 3), activation='relu'))
model_transfer_learning.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_transfer_learning.add(Conv2D(64, (3, 3), activation='relu'))
model_transfer_learning.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model_transfer_learning.add(Conv2D(64, (3, 3), activation='relu'))
model_transfer_learning.add(MaxPooling2D(pool_size=(2, 2)))
model_transfer_learning.add(Flatten())
model_transfer_learning.add(Dense(128, activation='relu'))
model_transfer_learning.add(Dense(10, activation='softmax'))

model_transfer_learning.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 24, 24, 32)        832
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 22, 22, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 20, 20, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 2, 2, 64)          36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 139,722
# Trainable params: 139,722
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### > Lendo o conjunto de pesos de uma arquitetura treinada no dataset MNIST:

# %%
model_transfer_learning.load_weights("model_transfer_learning.h5")

# %% [markdown]
# #### > "Congelando" os pesos das camadas convolucionais:

# %%
for layer in model_transfer_learning.layers[:-2]:
    layer.trainable = False
    
for layer in model_transfer_learning.layers:
    print(layer, layer.trainable)
# Out:
# <keras.layers.convolutional.Conv2D object at 0x000001E9CBB23860> False
# <keras.layers.convolutional.Conv2D object at 0x000001E9CDF53668> False
# <keras.layers.convolutional.Conv2D object at 0x000001E9CDF9A7B8> False
# <keras.layers.pooling.MaxPooling2D object at 0x000001E9CDF7AF28> False
# <keras.layers.convolutional.Conv2D object at 0x000001E9CEF97748> False
# <keras.layers.pooling.MaxPooling2D object at 0x000001E9CEFCAA58> False
# <keras.layers.convolutional.Conv2D object at 0x000001E9CF0046D8> False
# <keras.layers.pooling.MaxPooling2D object at 0x000001E9CF014CC0> False
# <keras.layers.core.Flatten object at 0x000001E9CF014C50> False
# <keras.layers.core.Dense object at 0x000001E9CF038588> True
# <keras.layers.core.Dense object at 0x000001E9CF038C50> True

# %% [markdown]
# #### > Removendo as camadas Fully Connected:

# %%
model_transfer_learning.layers.pop()
model_transfer_learning.layers.pop()
model_transfer_learning.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 24, 24, 32)        832
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 22, 22, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 20, 20, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 2, 2, 64)          36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 64)                0
# =================================================================
# Total params: 130,112
# Trainable params: 0
# Non-trainable params: 130,112
# _________________________________________________________________

# %% [markdown]
# #### > Adicionando novas camadas Fully-Connected para o nosso problema:

# %%
model_transfer_learning.add(Dense(128, activation='relu'))
model_transfer_learning.add(Dense(26, activation='softmax'))
model_transfer_learning.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 24, 24, 32)        832
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 22, 22, 64)        18496
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 20, 20, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 2, 2, 64)          36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               1408
# _________________________________________________________________
# dense_11 (Dense)             (None, 26)                3354
# =================================================================
# Total params: 134,874
# Trainable params: 4,762
# Non-trainable params: 130,112
# _________________________________________________________________

# %% [markdown]
# #### > Treinamento:

# %%
model_transfer_learning.compile(loss=categorical_crossentropy,
              optimizer=RMSprop(lr=0.01),
              metrics=['accuracy'])

history_transfer_learning = model_transfer_learning.fit(X_train, y_train2,
          batch_size=batch_size_value,
          epochs=50,
          verbose=1,
          validation_data=(X_val, y_test2))
# Out:
# Train on 3993 samples, validate on 999 samples
# Epoch 1/50
# 3993/3993 [==============================] - 1s 171us/step - loss: 3.1833 - acc: 0.0626 - val_loss: 3.0166 - val_acc: 0.0841
# Epoch 2/50
# 3993/3993 [==============================] - 0s 84us/step - loss: 2.7719 - acc: 0.1360 - val_loss: 2.7354 - val_acc: 0.1481
# Epoch 3/50
# 3993/3993 [==============================] - 0s 82us/step - loss:
50
# 3993/3993 [==============================] - 0s 83us/step - loss: 1.1976 - acc: 0.6013 - val_loss: 1.6402 - val_acc: 0.4905
# Epoch 33/50
# 3993/3993 [==============================] - 0s 83us/step - loss: 1.1641 - acc: 0.6176 - val_loss: 1.4116 - val_acc: 0.5576
# Epoch 34/50
# 3993/3993 [==============================] - 0s 83us/step - loss: 1.1447 - acc: 0.6256 - val_loss: 1.4563 - val_acc: 0.5345
# Epoch 35/50
# 3993/3993 [==============================] - 0s 87us/step - loss: 1.1327 - acc: 0.6289 - val_loss: 1.7189 - val_acc: 0.4825
# Epoch 36/50
# 3993/3993 [==============================] - 0s 87us/step - loss: 1.1028 - acc: 0.6434 - val_loss: 1.6835 - val_acc: 0.4935
# Epoch 37/50
# 3993/3993 [==============================] - 0s 89us/step - loss: 1.1098 - acc: 0.6346 - val_loss: 1.4531 - val_acc: 0.5596
# Epoch 38/50
# 3993/3993 [==============================] - 0s 87us/step - loss: 1.0842 - acc: 0.6486 - val_loss: 1.3046 - val_acc: 0.6046
# Epoch 39/50
# 3993/3993 [==============================] - 0s 89us/step - loss: 1.0451 - acc: 0.6569 - val_loss: 1.4321 - val_acc: 0.5806
# Epoch 40/50
# 3993/3993 [==============================] - 0s 89us/step - loss: 1.0277 - acc: 0.6664 - val_loss: 1.3918 - val_acc: 0.5636
# Epoch 41/50
# 3993/3993 [==============================] - 0s 87us/step - loss: 1.0308 - acc: 0.6582 - val_loss: 1.3559 - val_acc: 0.5886
# Epoch 42/50
# 3993/3993 [==============================] - 0s 86us/step - loss: 0.9942 - acc: 0.6754 - val_loss: 1.3142 - val_acc: 0.5866
# Epoch 43/50
# 3993/3993 [==============================] - 0s 87us/step - loss: 0.9773 - acc: 0.6812 - val_loss: 1.2391 - val_acc: 0.6036
# Epoch 44/50
# 3993/3993 [==============================] - 0s 83us/step - loss: 0.9899 - acc: 0.6777 - val_loss: 1.3228 - val_acc: 0.5906
# Epoch 45/50
# 3993/3993 [==============================] - 0s 90us/step - loss: 0.9446 - acc: 0.6980 - val_loss: 1.3371 - val_acc: 0.5796
# Epoch 46/50
# 3993/3993 [==============================] - 0s 86us/step - loss: 0.9314 - acc: 0.6912 - val_loss: 1.6158 - val_acc: 0.5385
# Epoch 47/50
# 3993/3993 [==============================] - 0s 86us/step - loss: 0.9385 - acc: 0.6970 - val_loss: 1.5335 - val_acc: 0.5556
# Epoch 48/50
# 3993/3993 [==============================] - 0s 86us/step - loss: 0.9223 - acc: 0.6905 - val_loss: 1.2744 - val_acc: 0.6226
# Epoch 49/50
# 3993/3993 [==============================] - 0s 85us/step - loss: 0.8949 - acc: 0.7005 - val_loss: 1.1235 - val_acc: 0.6647
# Epoch 50/50
# 3993/3993 [==============================] - 0s 87us/step - loss: 0.8889 - acc: 0.7072 - val_loss: 1.1559 - val_acc: 0.6466

# %% [markdown]
# #### > Exibindo o desempenho:

# %%
plt.plot(history_transfer_learning.history['acc'])
plt.plot(history_transfer_learning.history['val_acc'])
plt.ylabel('acurácia')
plt.xlabel('época')
plt.legend(['treino', 'teste'], loc = 'upper left')
plt.show()

plt.plot(history_transfer_learning.history['loss'])
plt.plot(history_transfer_learning.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('época')
plt.legend(['treino', 'teste'], loc = 'upper left')
plt.show()
